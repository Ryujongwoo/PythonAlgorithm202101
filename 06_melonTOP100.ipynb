# %%
import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup

# %%
# targetSite = 'https://www.melon.com/chart/index.htm'
# request = requests.get(targetSite)
# print(request) # <Response [406]> => 헤더 문제로 사이트의 요청한 정보를 얻어올 수 없다.

# %%
targetSite = 'https://www.melon.com/chart/index.htm'
h = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers = h)
# print(request)

# %%
html = request.text
# print(html)
soup = BeautifulSoup(html)
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('div', {'class': 'ellipsis rank01'})
# print(titles)
# print(len(titles))

for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 밤하늘의 별을(2020)
# Dynamite
# 잠이 오질 않네요
# Lovesick Girls
# 취기를 빌려 (취향저격 그녀 X 산들)
# 힘든 건 사랑이 아니다
# 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
# Rosario (Feat. CL, ZICO)
# 내 얘기 같아 (Feat. 헤이즈)
# Life Goes On
# 오래된 노래
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 화(火花)
# 에잇(Prod.&Feat. SUGA of BTS)
# 혼술하고 싶은 밤
# CREDIT (Feat. 염따, 기리보이, Zion.T)
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Blueming
# 늦은 밤 너의 집 앞 골목길에서
# When We Disco (Duet with 선미)
# 모든 날, 모든 순간 (Every day, Every Moment)
# 어떻게 지내 (Prod. By VAN.C)
# Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
# METEOR
# How You Like That
# 아로하
# 사실 나는 (Feat.전건호)
# Dolphin
# 서면역에서
# 그날에 나는 맘이 편했을까
# 마음을 드려요
# Freak (Prod. Slom)
# 딩가딩가 (Dingga)
# 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# ON AIR (Feat. 로꼬, 박재범 & GRAY)
# 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 2002
# Memories
# 거짓말이라도 해서 널 보고싶어
# DON'T TOUCH ME
# I CAN’T STOP ME
# 우리 왜 헤어져야 해
# 마리아 (Maria)
# 시작
# 봄날
# 사랑은 지날수록 더욱 선명하게 남아
# 정당방위 (Feat. 우원재, 넉살, 창모)
# 살짝 설렜어 (Nonstop)
# 한잔이면 지워질까
# Dance Monkey
# 홀로
# 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
# 뻔한남자
# 눈누난나 (NUNU NANA)
# 안녕
# Downtown Baby
# Panorama
# 너의 번호를 누르고 (Prod. 영화처럼)
# 사랑 못해, 남들 쉽게 다 하는 거
# 너를 만나
# 가을밤에 든 생각
# Love poem
# 소확행
# 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
# 처음처럼
# Snowman
# 우린 어쩌다 헤어진 걸까
# 잘할게
# 이제 나만 믿어요
# 행복해
# 사랑하게 될 줄 알았어
# What Do I Call You
# Don't Start Now
# 수상소감 (Feat. B.I)
# 12:45 (Stripped)
# 나로 바꾸자 (duet with JYP)
# Black Mamba
# Bad Boy
# 별을 담은 시 (Ode To The Stars)
# 아무노래
# Paris In The Rain
# Maniac
# 여백의 미 (Feat. Jessi, JUSTHIS) (Prod. GroovyRoom)
# 너도 아는
# 12월의 어느 겨울…
# 다시 여기 바닷가
# ON
# 밝게 빛나는 별이 되어 비춰줄게
# 놓아줘 (with 태연)
# Santa Tell Me
# 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
# Blue & Grey
# 적외선 카메라
# All I Want For Christmas Is You
# For You (Feat. Crush)

# %%
# 아티스트 크롤링
artists = soup.findAll('span', {'class': 'checkEllipsis'})
# print(artists)
# print(len(artists))

for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[0])
    print(artist.text.strip().split('\n')[0])
# Out:
# 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM)
# 경서
# 방탄소년단
# 장범준
# BLACKPINK
# 산들
# 임창정
# 릴보이 (lIlBOI)
# 에픽하이 (EPIK HIGH)
# 에픽하이 (EPIK HIGH)
# 방탄소년단
# 스탠딩 에그
# Jawsh 685, Jason Derulo, 방탄소년단
# 규현 (KYUHYUN)
# 적재
# (여자)아이들
# 아이유
# 벤
# 릴보이 (lIlBOI)
# AKMU (악동뮤지션)
# 장범준
# 아이유
# 노을
# 박진영
# 폴킴
# 오반 (OVAN)
# 미란이 (Mirani)
# 창모 (CHANGMO)
# BLACKPINK
# 조정석
# 경서예지
# 오마이걸 (OH MY GIRL)
# 순순희
# 이예준
# 아이유
# 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk)
# 마마무 (Mamamoo)
# 마크툽 (MAKTUB)
# 릴보이 (lIlBOI)
# Khundi Panda
# 방탄소년단
# Anne-Marie
# Maroon 5
# 백지영
# 환불원정대
# TWICE (트와이스)
# 신예영
# 화사 (Hwa Sa)
# 가호 (Gaho)
# 방탄소년단
# 전상근
# 에픽하이 (EPIK HIGH)
# 오마이걸 (OH MY GIRL)
# 황인욱
# Tones And I
# 이하이
# 스윙스
# 이승기
# 제시 (Jessi)
# 폴킴
# 블루 (BLOO)
# IZ*ONE (아이즈원)
# #안녕
# 먼데이 키즈 (Monday Kiz)
# 폴킴
# 잔나비
# 아이유
# 임창정
# 머쉬베놈 (MUSHVENOM)
# 엠씨더맥스 (M.C the MAX)
# Sia
# 허각
# 이승기
# 임영웅
# 송하예
# 전미도
# 태연 (TAEYEON)
# Dua Lipa
# 에픽하이 (EPIK HIGH)
# Etham
# 비
# aespa
# 청하, Christopher
# 마크툽 (MAKTUB), 이라온
# 지코 (ZICO)
# Lauv
# Conan Gray
# 머쉬베놈 (MUSHVENOM)
# 폴킴
# 윤도 (YoonDo)
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 방탄소년단
# 송이한
# Crush
# Ariana Grande
# 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone)
# 방탄소년단
# 원슈타인
# Mariah Carey
# 이하이

# %%
from datetime import datetime as dt
print(dt.now())
for i in range(len(titles)):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-01-19 20:52:34.701407
#   1위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   2위 경서 - 밤하늘의 별을(2020)
#   3위 방탄소년단 - Dynamite
#   4위 장범준 - 잠이 오질 않네요
#   5위 BLACKPINK - Lovesick Girls
#   6위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#   7위 임창정 - 힘든 건 사랑이 아니다
#   8위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#   9위 에픽하이 (EPIK HIGH) - Rosario (Feat. CL, ZICO)
#  10위 에픽하이 (EPIK HIGH) - 내 얘기 같아 (Feat. 헤이즈)
#  11위 방탄소년단 - Life Goes On
#  12위 스탠딩 에그 - 오래된 노래
#  13위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  14위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  15위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  16위 (여자)아이들 - 화(火花)
#  17위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  18위 벤 - 혼술하고 싶은 밤
#  19위 릴보이 (lIlBOI) - CREDIT (Feat. 염따, 기리보이, Zion.T)
#  20위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  21위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  22위 아이유 - Blueming
#  23위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  24위 박진영 - When We Disco (Duet with 선미)
#  25위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  26위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  27위 미란이 (Mirani) - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  28위 창모 (CHANGMO) - METEOR
#  29위 BLACKPINK - How You Like That
#  30위 조정석 - 아로하
#  31위 경서예지 - 사실 나는 (Feat.전건호)
#  32위 오마이걸 (OH MY GIRL) - Dolphin
#  33위 순순희 - 서면역에서
#  34위 이예준 - 그날에 나는 맘이 편했을까
#  35위 아이유 - 마음을 드려요
#  36위 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk) - Freak (Prod. Slom)
#  37위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
#  38위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  39위 릴보이 (lIlBOI) - ON AIR (Feat. 로꼬, 박재범 & GRAY)
#  40위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  41위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  42위 Anne-Marie - 2002
#  43위 Maroon 5 - Memories
#  44위 백지영 - 거짓말이라도 해서 널 보고싶어
#  45위 환불원정대 - DON'T TOUCH ME
#  46위 TWICE (트와이스) - I CAN’T STOP ME
#  47위 신예영 - 우리 왜 헤어져야 해
#  48위 화사 (Hwa Sa) - 마리아 (Maria)
#  49위 가호 (Gaho) - 시작
#  50위 방탄소년단 - 봄날
#  51위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  52위 에픽하이 (EPIK HIGH) - 정당방위 (Feat. 우원재, 넉살, 창모)
#  53위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  54위 황인욱 - 한잔이면 지워질까
#  55위 Tones And I - Dance Monkey
#  56위 이하이 - 홀로
#  57위 스윙스 - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#  58위 이승기 - 뻔한남자
#  59위 제시 (Jessi) - 눈누난나 (NUNU NANA)
#  60위 폴킴 - 안녕
#  61위 블루 (BLOO) - Downtown Baby
#  62위 IZ*ONE (아이즈원) - Panorama
#  63위 #안녕 - 너의 번호를 누르고 (Prod. 영화처럼)
#  64위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  65위 폴킴 - 너를 만나
#  66위 잔나비 - 가을밤에 든 생각
#  67위 아이유 - Love poem
#  68위 임창정 - 소확행
#  69위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  70위 엠씨더맥스 (M.C the MAX) - 처음처럼
#  71위 Sia - Snowman
#  72위 허각 - 우린 어쩌다 헤어진 걸까
#  73위 이승기 - 잘할게
#  74위 임영웅 - 이제 나만 믿어요
#  75위 송하예 - 행복해
#  76위 전미도 - 사랑하게 될 줄 알았어
#  77위 태연 (TAEYEON) - What Do I Call You
#  78위 Dua Lipa - Don't Start Now
#  79위 에픽하이 (EPIK HIGH) - 수상소감 (Feat. B.I)
#  80위 Etham - 12:45 (Stripped)
#  81위 비 - 나로 바꾸자 (duet with JYP)
#  82위 aespa - Black Mamba
#  83위 청하, Christopher - Bad Boy
#  84위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
#  85위 지코 (ZICO) - 아무노래
#  86위 Lauv - Paris In The Rain
#  87위 Conan Gray - Maniac
#  88위 머쉬베놈 (MUSHVENOM) - 여백의 미 (Feat. Jessi, JUSTHIS) (Prod. GroovyRoom)
#  89위 폴킴 - 너도 아는
#  90위 윤도 (YoonDo) - 12월의 어느 겨울…
#  91위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  92위 방탄소년단 - ON
#  93위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  94위 Crush - 놓아줘 (with 태연)
#  95위 Ariana Grande - Santa Tell Me
#  96위 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
#  97위 방탄소년단 - Blue & Grey
#  98위 원슈타인 - 적외선 카메라
#  99위 Mariah Carey - All I Want For Christmas Is You
# 100위 이하이 - For You (Feat. Crush)

# %%
file = open('melonTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
file.close()
print('melonTOP100.txt 파일로 쓰기 완료')
# Out:
# melonTOP100.txt 파일로 쓰기 완료

# %%
try:
    file = open('melonTOP100.txt', 'r', -1, 'UTF-8')
    lines = file.readlines()
    for line in lines:
        print(line, end = '')
except:
    print('디스크에 파일이 없습니다.')
# Out:
# 2021-01-19 21:05:57.975168 현재 Bugs 뮤직 실시간 TOP 100
#   1위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#   2위 경서 - 밤하늘의 별을(2020)
#   3위 방탄소년단 - Dynamite
#   4위 장범준 - 잠이 오질 않네요
#   5위 BLACKPINK - Lovesick Girls
#   6위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#   7위 임창정 - 힘든 건 사랑이 아니다
#   8위 릴보이 (lIlBOI) - 내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))
#   9위 에픽하이 (EPIK HIGH) - Rosario (Feat. CL, ZICO)
#  10위 에픽하이 (EPIK HIGH) - 내 얘기 같아 (Feat. 헤이즈)
#  11위 방탄소년단 - Life Goes On
#  12위 스탠딩 에그 - 오래된 노래
#  13위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  14위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  15위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  16위 (여자)아이들 - 화(火花)
#  17위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  18위 벤 - 혼술하고 싶은 밤
#  19위 릴보이 (lIlBOI) - CREDIT (Feat. 염따, 기리보이, Zion.T)
#  20위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  21위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  22위 아이유 - Blueming
#  23위 노을 - 늦은 밤 너의 집 앞 골목길에서
#  24위 박진영 - When We Disco (Duet with 선미)
#  25위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  26위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  27위 미란이 (Mirani) - Achoo (Feat. pH-1, HAON) (Prod. GroovyRoom)
#  28위 창모 (CHANGMO) - METEOR
#  29위 BLACKPINK - How You Like That
#  30위 조정석 - 아로하
#  31위 경서예지 - 사실 나는 (Feat.전건호)
#  32위 오마이걸 (OH MY GIRL) - Dolphin
#  33위 순순희 - 서면역에서
#  34위 이예준 - 그날에 나는 맘이 편했을까
#  35위 아이유 - 마음을 드려요
#  36위 릴보이 (lIlBOI), 원슈타인, Chillin Homie, 스카이민혁 (Skyminhyuk) - Freak (Prod. Slom)
#  37위 마마무 (Mamamoo) - 딩가딩가 (Dingga)
#  38위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  39위 릴보이 (lIlBOI) - ON AIR (Feat. 로꼬, 박재범 & GRAY)
#  40위 Khundi Panda - 뿌리 (Feat. JUSTHIS) (Prod. GroovyRoom)
#  41위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  42위 Anne-Marie - 2002
#  43위 Maroon 5 - Memories
#  44위 백지영 - 거짓말이라도 해서 널 보고싶어
#  45위 환불원정대 - DON'T TOUCH ME
#  46위 TWICE (트와이스) - I CAN’T STOP ME
#  47위 신예영 - 우리 왜 헤어져야 해
#  48위 화사 (Hwa Sa) - 마리아 (Maria)
#  49위 가호 (Gaho) - 시작
#  50위 방탄소년단 - 봄날
#  51위 전상근 - 사랑은 지날수록 더욱 선명하게 남아
#  52위 에픽하이 (EPIK HIGH) - 정당방위 (Feat. 우원재, 넉살, 창모)
#  53위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  54위 황인욱 - 한잔이면 지워질까
#  55위 Tones And I - Dance Monkey
#  56위 이하이 - 홀로
#  57위 스윙스 - 악역 (Feat. 이하이 & 사이먼 도미닉) (Prod. 코드 쿤스트)
#  58위 이승기 - 뻔한남자
#  59위 제시 (Jessi) - 눈누난나 (NUNU NANA)
#  60위 폴킴 - 안녕
#  61위 블루 (BLOO) - Downtown Baby
#  62위 IZ*ONE (아이즈원) - Panorama
#  63위 #안녕 - 너의 번호를 누르고 (Prod. 영화처럼)
#  64위 먼데이 키즈 (Monday Kiz) - 사랑 못해, 남들 쉽게 다 하는 거
#  65위 폴킴 - 너를 만나
#  66위 잔나비 - 가을밤에 든 생각
#  67위 아이유 - Love poem
#  68위 임창정 - 소확행
#  69위 머쉬베놈 (MUSHVENOM) - 고독하구만 (Feat. 수퍼비) (Prod. GroovyRoom)
#  70위 엠씨더맥스 (M.C the MAX) - 처음처럼
#  71위 Sia - Snowman
#  72위 허각 - 우린 어쩌다 헤어진 걸까
#  73위 이승기 - 잘할게
#  74위 임영웅 - 이제 나만 믿어요
#  75위 송하예 - 행복해
#  76위 전미도 - 사랑하게 될 줄 알았어
#  77위 태연 (TAEYEON) - What Do I Call You
#  78위 Dua Lipa - Don't Start Now
#  79위 에픽하이 (EPIK HIGH) - 수상소감 (Feat. B.I)
#  80위 Etham - 12:45 (Stripped)
#  81위 비 - 나로 바꾸자 (duet with JYP)
#  82위 aespa - Black Mamba
#  83위 청하, Christopher - Bad Boy
#  84위 마크툽 (MAKTUB), 이라온 - 별을 담은 시 (Ode To The Stars)
#  85위 지코 (ZICO) - 아무노래
#  86위 Lauv - Paris In The Rain
#  87위 Conan Gray - Maniac
#  88위 머쉬베놈 (MUSHVENOM) - 여백의 미 (Feat. Jessi, JUSTHIS) (Prod. GroovyRoom)
#  89위 폴킴 - 너도 아는
#  90위 윤도 (YoonDo) - 12월의 어느 겨울…
#  91위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  92위 방탄소년단 - ON
#  93위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  94위 Crush - 놓아줘 (with 태연)
#  95위 Ariana Grande - Santa Tell Me
#  96위 스윙스, 맥대디 (Mckdaddy), Khakii (카키), 래원 (Layone) - 원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)
#  97위 방탄소년단 - Blue & Grey
#  98위 원슈타인 - 적외선 카메라
#  99위 Mariah Carey - All I Want For Christmas Is You
# 100위 이하이 - For You (Feat. Crush)
